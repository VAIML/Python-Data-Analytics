# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = pd.read_csv('Airbnb_Open_Data.csv')
df = pd.DataFrame(file)
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_3648\1492880517.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   file = pd.read_csv('Airbnb_Open_Data.csv')

# %%
df.shape
# Out:
# (102599, 26)

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
df.drop(columns=['license'], inplace=True)

# %%
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ...  price service fee minimum nights  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
df['neighbourhood group'].nunique()
# Out:
# 7

# %%
neighbour_group = df.groupby('neighbourhood group')['NAME'].count()

# %%
print (neighbour_group)
# Out:
# neighbourhood group
# Bronx             2704
# Brooklyn         41734
# Manhattan        43689
# Queens           13239
# Staten Island      954
# brookln              1
# manhatan             1
# Name: NAME, dtype: int64

# %%
df.drop(columns = 'id', inplace = True)

# %%
for i in df.columns:
    abc = df.groupby(i)['NAME'].count()
    print (i) 
    print (abc)
# Out:
# NAME
# NAME
#  Private 1 bdrm Lefferts Gr, BK apt                   2
# ! ! ! Coliving: live, work, create                    4
# !! CLASSIC, LUXURY & CHARM !! By Central Park UWS     2
# !!! Beautiful private room with backyard.             4
# !!! Outpost Coliving . Shared twin room               4
#                                                      ..
# 🥰Lovely 1 bedroom/5 minutes walk to timessquare       1
# 🧑🏼‍✈️Private Room LGA ✈️                              1
# 🪁LARGE PRIVATE TERRACE 🚶‍♂️8 MIN WALK TO MAIN ST      1
# 🪴XL dojo 🌾 shared green yogi palace apt 🌿             1
# 🪴🛋🌞 Unique sunny clean brownstone studio 1st floor    1
# Name: NAME, Length: 61281, dtype: int64
# host_identity_verified
# host_identity_verified
# unconfirmed    51083
# verified       50989
# Name: NAME, dtype: int64
# host name
# host name
# #NAME?                      2
# 'Cil                        1
# (Ari) HENRY LEE             2
# (Email hidden by Airbnb)    8
# ...

# %%
df.columns
# Out:
# Index(['NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules'],
#       dtype='object')

# %%
df.rename(columns = {'NAME': 'Name'})
# Out:
#                                                     Name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
useless_col = ['lat', 'long', 'country', 'country code']
df.drop (columns = useless_col, inplace = True)

# %%
df.columns
# Out:
# Index(['NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'instant_bookable',
#        'cancellation_policy', 'room type', 'Construction year', 'price',
#        'service fee', 'minimum nights', 'number of reviews', 'last review',
#        'reviews per month', 'review rate number',
#        'calculated host listings count', 'availability 365', 'house_rules'],
#       dtype='object')

# %%
df['house_rules'].unique()
# Out:
# array(["Clean up and treat the home the way you'd like your home to be treated.  No smoking.",
#        'Pet friendly but please confirm with me if the pet you are planning on bringing with you is OK. I have a cute and quiet mixed chihuahua. I could accept more guests (for an extra fee) but this also needs to be confirmed beforehand. Also friends traveling together could sleep in separate beds for an extra fee (the second bed is either a sofa bed or inflatable bed). Smoking is only allowed on the porch.',
#        "I encourage you to use my kitchen, cooking and laundry facilities. There is no additional charge to use the washer/dryer in the basement.  No smoking, inside or outside. Come home as late as you want.  If you come home stumbling drunk, it's OK the first time. If you do it again, and you wake up me or the neighbors downstairs, we will be annoyed.  (Just so you know . . . )",
#        ...,
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   NAME                            102349 non-null  object
#  1   host id                         102599 non-null  int64
#  2   host_identity_verified          102310 non-null  object
#  3   host name                       102193 non-null  object
#  4   neighbourhood group             102570 non-null  object
#  5   neighbourhood                   102583 non-null  object
#  6   instant_bookable                102494 non-null  object
#  7   cancellation_policy             102523 non-null  object
#  8   room type                       102599 non-null  object
#  9   Construction year               102385 non-null  float64
#  10  price                           102352 non-null  object
#  11  service fee                     102326 non-null  object
# ...

# %%
df[['house_rules']].to_excel('outputText.xlsx')

# %%
df.drop(columns = 'host id', inplace = True)

# %%
df.head()
# Out:
#                                                NAME      host id  \
# 0                Clean & quiet apt home by the park  80014485718
# 1                             Skylit Midtown Castle  52335172823
# 2               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                               NaN  85098326012
# 4  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#   instant_bookable cancellation_policy        room type  Construction year  \
# 0            False              strict     Private room             2020.0
# ...

# %%
df.drop(columns = 'host id', inplace = True)

# %%
for i in df.columns:
    a = df[i].nunique()
    print ('value for', i, ' is ', a)
# Out:
# value for NAME  is  61281
# value for host_identity_verified  is  2
# value for host name  is  13190
# value for neighbourhood group  is  7
# value for neighbourhood  is  224
# value for instant_bookable  is  2
# value for cancellation_policy  is  3
# value for room type  is  4
# value for Construction year  is  20
# value for price  is  1151
# value for service fee  is  231
# value for minimum nights  is  153
# value for number of reviews  is  476
# value for last review  is  2477
# value for reviews per month  is  1016
# value for review rate number  is  5
# value for calculated host listings count  is  78
# value for availability 365  is  438

# %%
df['minimum nights']= df['minimum nights'].fillna(0).astype(int)

# %%
df['service fee'] = df['service fee'].astype(str).str.replace('$', '', regex=False)
df['service fee'] = pd.to_numeric(df['service fee'], errors='coerce').fillna(0).astype(int)

# %%
df['service fee'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 102599 entries, 0 to 102598
# Series name: service fee
# Non-Null Count   Dtype
# --------------   -----
# 102599 non-null  int64
# dtypes: int64(1)
# memory usage: 801.7 KB

# %%
df['minimum nights'] = df['minimum nights'].astype(int)

# %%
df.head()
# Out:
#                                                NAME host_identity_verified  \
# 0                Clean & quiet apt home by the park            unconfirmed
# 1                             Skylit Midtown Castle               verified
# 2               THE VILLAGE OF HARLEM....NEW YORK !                    NaN
# 3                                               NaN            unconfirmed
# 4  Entire Apt: Spacious Studio/Loft by central park               verified
#
#   host name neighbourhood group neighbourhood instant_bookable  \
# 0  Madaline            Brooklyn    Kensington            False
# 1     Jenna           Manhattan       Midtown            False
# 2     Elise           Manhattan        Harlem             True
# 3     Garry            Brooklyn  Clinton Hill             True
# 4    Lyndon           Manhattan   East Harlem            False
#
#   cancellation_policy        room type  Construction year  price  service fee  \
# ...

# %%
cv = ['calculated host listings count']
for i in df.columns:
    if i in cv:
        df[i] = df[i].fillna(0)
        df[i] = df[i].astype(int)
    else:
        continue

df.head()
# Out:
#                                                NAME host_identity_verified  \
# 0                Clean & quiet apt home by the park            unconfirmed
# 1                             Skylit Midtown Castle               verified
# 2               THE VILLAGE OF HARLEM....NEW YORK !                    NaN
# 3                                               NaN            unconfirmed
# 4  Entire Apt: Spacious Studio/Loft by central park               verified
#
#   host name neighbourhood group neighbourhood instant_bookable  \
# 0  Madaline            Brooklyn    Kensington            False
# 1     Jenna           Manhattan       Midtown            False
# 2     Elise           Manhattan        Harlem             True
# 3     Garry            Brooklyn  Clinton Hill             True
# 4    Lyndon           Manhattan   East Harlem            False
#
#   cancellation_policy        room type  Construction year  price  service fee  \
# ...

# %%
df.tail(20)
# Out:
#                                                 NAME host_identity_verified  \
# 102579               Alexander's 2BR Luxury Quarters               verified
# 102580           Near LGA, Citifield, US Open Tennis               verified
# 102581  Bright Bedroom in Bustling Bed Stuy Brooklyn            unconfirmed
# 102582           Private room in the best part of BK               verified
# 102583                        1 BR apartment sublet.               verified
# 102584            2 block walk from the beach in NYC               verified
# 102585           Williamsburg family home -3 bedroom               verified
# 102586                Patio Oasis in Upper East Side               verified
# 102587             Adorable One-Bed in Williamsburg!               verified
# 102588      Loft Space for Events, Meetings & Shoots            unconfirmed
# 102589           Lrg room 1 block from Prospect Park            unconfirmed
# ...

# %%
bl = ['cancellation_policy', 'room type']

for i in df.columns:
    if i in bl :
        print (i,' value ',df[i].unique())
    else:
        continue
# Out:
# cancellation_policy  value  ['strict' 'moderate' 'flexible' nan]
# room type  value  ['Private room' 'Entire home/apt' 'Shared room' 'Hotel room']
