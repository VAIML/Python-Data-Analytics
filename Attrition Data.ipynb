# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('HR Employee data.csv')

# %%
df = pd.DataFrame(data)
df['MonthlyIncome'].min()
# Out:
# np.int64(1009)

# %%
df['MonthlyIncome'].hist()
plt.show()

# %%
df['JobSatisfaction'].hist()
# Out:
# <Axes: >

# %%
# Out:
# <Axes: >

# %%
sf.shape
# Out:
# (735, 39)

# %%
import seaborn as sns
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, y="PercentSalaryHike", x="MonthlyIncome", hue="Attrition", alpha=0.7)
# Out:
# <Axes: xlabel='MonthlyIncome', ylabel='PercentSalaryHike'>
